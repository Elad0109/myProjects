# %% [markdown]
# # Lab - working with online data

# %% [markdown]
# In this Lab , you will load , clean and store online flights data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import datetime
# %matplotlib inline

# %%
import requests
import json

# %% [markdown]
# # Load the data

# %%
r = requests.get("https://data.gov.il/api/3/action/datastore_search?resource_id=e83f763b-b7d7-479e-b172-ae981ddc6de5&limit=5000")

# %%
res = json.loads(r.content)

# %%
df = pd.DataFrame(res['result']['records'])

# %% [markdown]
# ## display the first rows

# %% [markdown]
# ### display the last 10 rows - What's wrong?

# %%
df.head(16)
# Out:
#     _id CHOPER CHFLTN                   CHOPERD               CHSTOL  \
# 0     1     IZ   1843  ARKIA  ISRAELI  AIRLINES  2024-03-02T16:50:00
# 1     2     LH    687                 LUFTHANSA  2024-03-02T16:45:00
# 2     3     SN   7174         BRUSSELS AIRLINES  2024-03-02T16:45:00
# 3     4     UA   9123           UNITED AIRLINES  2024-03-02T16:45:00
# 4     5     A4   5026          AZIMUTH AIRLINES  2024-03-02T17:35:00
# 5     6     IZ    829  ARKIA  ISRAELI  AIRLINES  2024-03-02T18:30:00
# 6     7     LX    253     SWISS INT`L  AIRLINES  2024-03-02T18:20:00
# 7     8     IZ   1844  ARKIA  ISRAELI  AIRLINES  2024-03-02T19:15:00
# 8     9     IZ    604  ARKIA  ISRAELI  AIRLINES  2024-03-02T18:40:00
# 9    10     U8    108               TUS AIRWAYS  2024-03-02T20:00:00
# 10   11     W9   4451                   WIZZ UK  2024-03-02T21:05:00
# 11   12     BZ    701         BLUE BIRD AIRWAYS  2024-03-02T15:35:00
# 12   13     IZ    820  ARKIA  ISRAELI  AIRLINES  2024-03-02T21:05:00
# 13   14     IZ   1845  ARKIA  ISRAELI  AIRLINES  2024-03-02T20:10:00
# 14   15     U8    109               TUS AIRWAYS  2024-03-02T21:00:00
# 15   16     IZ    212  ARKIA  ISRAELI  AIRLINES  2024-03-02T21:25:00
#
#                  CHPTOL CHAORD CHLOC1    CHLOC1D      CHLOC1TH       CHLOC1T  \
# 0   2024-03-02T17:17:00      D    ETM      RAMON   אילת - רמון         RAMON
# 1   2024-03-02T17:19:00      D    FRA  FRANKFURT      פרנקפורט     FRANKFURT
# 2   2024-03-02T17:19:00      D    FRA  FRANKFURT      פרנקפורט     FRANKFURT
# 3   2024-03-02T17:19:00      D    FRA  FRANKFURT      פרנקפורט     FRANKFURT
# 4   2024-03-02T17:40:00      D    AER      SOCHI         סוצ'י         SOCHI
# 5   2024-03-02T18:34:00      D    ETM      RAMON   אילת - רמון         RAMON
# 6   2024-03-02T18:42:00      D    ZRH     ZURICH         ציריך        ZURICH
# 7   2024-03-02T19:26:00      A    ETM      RAMON   אילת - רמון         RAMON
# 8   2024-03-02T19:31:00      A    DXB      DUBAI         דובאי         DUBAI
# 9   2024-03-02T19:51:00      A    LCA    LARNACA         לרנקה       LARNACA
# 10  2024-03-02T20:38:00      A    LTN      LUTON  לונדון לוטון  LONDON LUTON
# 11  2024-03-02T20:41:00      A    ATH     ATHENS         אתונה        ATHENS
# 12  2024-03-02T21:01:00      A    ETM      RAMON   אילת - רמון         RAMON
# 13  2024-03-02T21:06:00      D    ETM      RAMON   אילת - רמון         RAMON
# 14  2024-03-02T21:12:00      D    LCA    LARNACA         לרנקה       LARNACA
# 15  2024-03-02T21:23:00      A    ATH     ATHENS         אתונה        ATHENS
#
#                 CHLOC1CH               CHLOCCT  CHTERM   CHCINT CHCKZN  \
# 0                  ישראל                ISRAEL       3  G12-G18      G
# 1                 גרמניה               GERMANY       3    26-33      A
# 2                 גרמניה               GERMANY       3    26-33      A
# 3                 גרמניה               GERMANY       3    26-33      A
# 4                  רוסיה    RUSSIAN FEDERATION       3    56-58      C
# 5                  ישראל                ISRAEL       3  G12-G18      G
# 6                  שוויץ           SWITZERLAND       3    26-33      A
# 7                  ישראל                ISRAEL       3     None   None
# 8   איחוד האמירויות הערב  UNITED ARAB EMIRATES       3     None   None
# 9                קפריסין                CYPRUS       3     None   None
# 10               בריטניה        UNITED KINGDOM       3     None   None
# 11                  יוון                GREECE       3     None   None
# 12                 ישראל                ISRAEL       3     None   None
# 13                 ישראל                ISRAEL       3  G12-G18      G
# 14               קפריסין                CYPRUS       3    60-63      C
# 15                  יוון                GREECE       3     None   None
#
#      CHRMINE CHRMINH
# 0   DEPARTED  המריאה
# 1   DEPARTED  המריאה
# 2   DEPARTED  המריאה
# 3   DEPARTED  המריאה
# 4   DEPARTED  המריאה
# 5   DEPARTED  המריאה
# 6   DEPARTED  המריאה
# 7     LANDED    נחתה
# 8     LANDED    נחתה
# 9     LANDED    נחתה
# 10    LANDED    נחתה
# 11    LANDED    נחתה
# 12    LANDED    נחתה
# 13  DEPARTED  המריאה
# 14  DEPARTED  המריאה
# 15    LANDED    נחתה

# %% [markdown]
# # clean the data

# %% [markdown]
# how many rows contains empty strings for each Column? (use a for loop to display the column name and percentage)

# %% [markdown]
# drop the empty rows

# %% [markdown]
# format the current date with underscore separation (%d_%m_%y)

# %% [markdown]
# Drop the _id column

# %% [markdown]
# save the raw data (add the current date to the file name)

# %% [markdown]
# select the airline code and name without duplicates (CHOPER,CHOPERD)

# %% [markdown]
# Load the file airlines.csv and merge it with a new data and save the file 'airline.csv'

# %% [markdown]
# Drop the Airline name column CHOPERD

# %% [markdown]
# Do the same task with airports (CHLOC1,CHLOC1D) and save the file 'airports.csv'

# %% [markdown]
# drop the hebrew columns 'CHLOC1TH','CHLOC1CH','CHRMINH'

# %% [markdown]
# ### rename the columns

# %% [markdown]
# Change the PlanTime and ActualTime columns type to np.datetime64

# %% [markdown]
# Save the clean data

# %% [markdown]
# update the file final.csv with departed, landed and canceled flights only

# %% [markdown]
# Add a new column for total delay in minutes

# %% [markdown]
# What is the average delay for departed flights

# %% [markdown]
# create 5 diffrent graph's
